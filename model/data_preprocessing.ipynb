# %% [markdown]
# # Data Preprocessing for Health Check Data
#
# This notebook performs comprehensive data preprocessing on the health and nutrition datasets, including:
# - Data cleaning
# - Handling missing values
# - Removing duplicates
# - Data type conversions
# - Normalization
# - Data validation

# %% [markdown]
# ## 1. Load Required Libraries and Data Files
#
# First, we'll import the necessary libraries and load our datasets.

# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# Load the datasets
cnns_data = pd.read_csv('Comprehensive National Nutrition Survey (CNNS) 2016-18  Key Anthropometric Indicators by Sex.csv')
malnutrition_data = pd.read_csv('malnutrition_data (1).csv')
malnutrition_month = pd.read_csv('Malnutrition_month.csv')

# Display basic information about each dataset
print("CNNS Dataset Info:")
print(cnns_data.info())
print("\nMalnutrition Data Info:")
print(malnutrition_data.info())
print("\nMalnutrition Month Data Info:")
print(malnutrition_month.info())
# Out:
# CNNS Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 44 columns):
#  #   Column                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                --------------  -----
#  0   Rowid                                                                                                                                 62 non-null     int64
#  1   Country                                                                                                                               62 non-null     object
#  2   State lgd code                                                                                                                        62 non-null     int64
#  3   State                                                                                                                                 62 non-null     object
#  4   Yearcode                                                                                                                              62 non-null     int64
#  5   Year                                                                                                                                  62 non-null     object
#  6   From year                                                                                                                             62 non-null     int64
#  7   Gender                                                                                                                                62 non-null     object
#  8   Stunted (height for age) children under the age of 5 years (%)                                                                        62 non-null     float64
#  9   Severely stunted (height for age) children under the age of 5 years (%)                                                               62 non-null     float64
#  10  Wasted (weight for height) children under the age of 5 years (%)                                                                      62 non-null     float64
#  11  Severely wasted (weight for height) children under the age of 5 years (%)                                                             62 non-null     float64
#  12  Underweight children under the age of 5 years (%)                                                                                     62 non-null     float64
#  13  Severely underweight children under the age of 5 years (%)                                                                            62 non-null     float64
#  14  Children age group 6 to 59 months with mid-upper arm circumference ( muac ) less than 12.5 cm (%)                                     62 non-null     float64
#  15  Children age group 6 to 59 months with muac(mid-upper arm circumference) less than 11.5 cm (%)                                        62 non-null     float64
#  16  Children age group  6 to 59 months with mid-upper arm circumference ( muac ) for age less than -2 sd (%)                              62 non-null     float64
#  17  Children age group 6 to 59 months with mid-upper arm circumference ( muac ) for age less than -3 sd (%)                               62 non-null     float64
#  18  Children under the age 5 years with triceps skinfold (thickness-for-age) less than -2 sd (%)                                          62 non-null     float64
#  19  Children under the age 5 years with triceps skinfold (thickness-for-age) less than -3 sd (%)                                          62 non-null     float64
#  20  Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +2 sd (%)                                       62 non-null     float64
#  21  Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +3 sd (%)                                       62 non-null     float64
#  22  Children age group 1 to 4 years with subscapular skinfold (thickness for age) less than -2 sd (%)                                     62 non-null     float64
#  23  Children age group of 1 to 4 years with subscapular skinfold (thickness for age) less than -3 sd (%)                                  62 non-null     float64
#  24  Children age group 1 to 4 years subscapular skinfold (thickness for age) greater than +2 sd (%)                                       62 non-null     float64
#  25  Children age group 1 to 4 years with subscapular skinfold (thickness for age) greater than +3 sd (%)                                  62 non-null     float64
#  26  Stunned children age group 5 to 9 years (%)                                                                                           62 non-null     float64
#  27  Severely stunted children age group of 5 to 9 years (%)                                                                               62 non-null     float64
#  28  Moderate or severely thin children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)         62 non-null     float64
#  29  Severely thin children in the age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)              62 non-null     float64
#  30  Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +1 sd (%)            62 non-null     float64
#  31  Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +2 sd (%)            62 non-null     float64
#  32  Moderate or severely thin adolescents age group 10 to14 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)     62 non-null     float64
#  33  Moderate or severely thin adolescents age group of 15 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  62 non-null     float64
#  34  Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)     62 non-null     float64
#  35  Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                62 non-null     float64
#  36  Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)                62 non-null     float64
#  37  Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)               62 non-null     float64
#  38  Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)      62 non-null     float64
#  39  Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)       62 non-null     float64
#  40  Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)      62 non-null     float64
#  41  Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                    62 non-null     float64
#  42  Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                    62 non-null     float64
#  43  Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                    62 non-null     float64
# dtypes: float64(36), int64(4), object(4)
# memory usage: 21.4+ KB
# None
#
# Malnutrition Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_months        5000 non-null   float64
#  1   weight_kg         5000 non-null   float64
#  2   height_cm         5000 non-null   float64
#  3   muac_cm           5000 non-null   float64
#  4   bmi               5000 non-null   float64
#  5   nutrition_status  5000 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 234.5+ KB
# None
#
# Malnutrition Month Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Sex,Weight,Height,Month,BMI,Result  1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 44 columns):
#  #   Column                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                --------------  -----
#  0   Rowid                                                                                                                                 62 non-null     int64
#  1   Country                                                                                                                               62 non-null     object
#  2   State lgd code                                                                                                                        62 non-null     int64
#  3   State                                                                                                                                 62 non-null     object
#  4   Yearcode                                                                                                                              62 non-null     int64
#  5   Year                                                                                                                                  62 non-null     object
#  6   From year                                                                                                                             62 non-null     int64
#  7   Gender                                                                                                                                62 non-null     object
#  8   Stunted (height for age) children under the age of 5 years (%)                                                                        62 non-null     float64
#  9   Severely stunted (height for age) children under the age of 5 years (%)                                                               62 non-null     float64
#  10  Wasted (weight for height) children under the age of 5 years (%)                                                                      62 non-null     float64
#  11  Severely wasted (weight for height) children under the age of 5 years (%)                                                             62 non-null     float64
#  12  Underweight children under the age of 5 years (%)                                                                                     62 non-null     float64
#  13  Severely underweight children under the age of 5 years (%)                                                                            62 non-null     float64
#  14  Children age group 6 to 59 months with mid-upper arm circumference ( muac ) less than 12.5 cm (%)                                     62 non-null     float64
#  15  Children age group 6 to 59 months with muac(mid-upper arm circumference) less than 11.5 cm (%)                                        62 non-null     float64
#  16  Children age group  6 to 59 months with mid-upper arm circumference ( muac ) for age less than -2 sd (%)                              62 non-null     float64
#  17  Children age group 6 to 59 months with mid-upper arm circumference ( muac ) for age less than -3 sd (%)                               62 non-null     float64
#  18  Children under the age 5 years with triceps skinfold (thickness-for-age) less than -2 sd (%)                                          62 non-null     float64
#  19  Children under the age 5 years with triceps skinfold (thickness-for-age) less than -3 sd (%)                                          62 non-null     float64
#  20  Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +2 sd (%)                                       62 non-null     float64
#  21  Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +3 sd (%)                                       62 non-null     float64
#  22  Children age group 1 to 4 years with subscapular skinfold (thickness for age) less than -2 sd (%)                                     62 non-null     float64
#  23  Children age group of 1 to 4 years with subscapular skinfold (thickness for age) less than -3 sd (%)                                  62 non-null     float64
#  24  Children age group 1 to 4 years subscapular skinfold (thickness for age) greater than +2 sd (%)                                       62 non-null     float64
#  25  Children age group 1 to 4 years with subscapular skinfold (thickness for age) greater than +3 sd (%)                                  62 non-null     float64
#  26  Stunned children age group 5 to 9 years (%)                                                                                           62 non-null     float64
#  27  Severely stunted children age group of 5 to 9 years (%)                                                                               62 non-null     float64
#  28  Moderate or severely thin children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)         62 non-null     float64
#  29  Severely thin children in the age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)              62 non-null     float64
#  30  Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +1 sd (%)            62 non-null     float64
#  31  Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +2 sd (%)            62 non-null     float64
#  32  Moderate or severely thin adolescents age group 10 to14 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)     62 non-null     float64
#  33  Moderate or severely thin adolescents age group of 15 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  62 non-null     float64
#  34  Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)     62 non-null     float64
#  35  Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                62 non-null     float64
#  36  Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)                62 non-null     float64
#  37  Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)               62 non-null     float64
#  38  Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)      62 non-null     float64
#  39  Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)       62 non-null     float64
#  40  Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)      62 non-null     float64
#  41  Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                    62 non-null     float64
#  42  Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                    62 non-null     float64
#  43  Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                    62 non-null     float64
# dtypes: float64(36), int64(4), object(4)
# memory usage: 21.4+ KB
# None
#
# Malnutrition Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_months        5000 non-null   float64
#  1   weight_kg         5000 non-null   float64
#  2   height_cm         5000 non-null   float64
#  3   muac_cm           5000 non-null   float64
#  4   bmi               5000 non-null   float64
#  5   nutrition_status  5000 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 234.5+ KB
# None
#
# Malnutrition Month Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Sex,Weight,Height,Month,BMI,Result  1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB
# None

# %% [markdown]
# ## 2. Handle Missing Values
#
# Let's identify and handle missing values in each dataset.

# %%
# Check missing values in each dataset
print("Missing values in CNNS dataset:")
print(cnns_data.isnull().sum())
print("\nMissing values in Malnutrition dataset:")
print(malnutrition_data.isnull().sum())
print("\nMissing values in Malnutrition Month dataset:")
print(malnutrition_month.isnull().sum())

# Handle missing values in CNNS dataset
cnns_data_clean = cnns_data.copy()
# Fill numeric columns with median
numeric_columns = cnns_data_clean.select_dtypes(include=[np.number]).columns
cnns_data_clean[numeric_columns] = cnns_data_clean[numeric_columns].fillna(cnns_data_clean[numeric_columns].median())
# Fill categorical columns with mode
categorical_columns = cnns_data_clean.select_dtypes(exclude=[np.number]).columns
cnns_data_clean[categorical_columns] = cnns_data_clean[categorical_columns].fillna(cnns_data_clean[categorical_columns].mode().iloc[0])

# Handle missing values in Malnutrition dataset
malnutrition_data_clean = malnutrition_data.copy()
malnutrition_data_clean = malnutrition_data_clean.fillna(method='ffill').fillna(method='bfill')

# Handle missing values in Malnutrition Month dataset
malnutrition_month_clean = malnutrition_month.copy()
malnutrition_month_clean = malnutrition_month_clean.fillna(method='ffill').fillna(method='bfill')

# Verify missing values have been handled
print("\nVerifying missing values after cleaning:")
print("\nCNNS dataset missing values:")
print(cnns_data_clean.isnull().sum().sum())
print("\nMalnutrition dataset missing values:")
print(malnutrition_data_clean.isnull().sum().sum())
print("\nMalnutrition Month dataset missing values:")
print(malnutrition_month_clean.isnull().sum().sum())
# Out:
# Missing values in CNNS dataset:
# Rowid                                                                                                                                   0
# Country                                                                                                                                 0
# State lgd code                                                                                                                          0
# State                                                                                                                                   0
# Yearcode                                                                                                                                0
# Year                                                                                                                                    0
# From year                                                                                                                               0
# Gender                                                                                                                                  0
# Stunted (height for age) children under the age of 5 years (%)                                                                          0
# Severely stunted (height for age) children under the age of 5 years (%)                                                                 0
# Wasted (weight for height) children under the age of 5 years (%)                                                                        0
# Severely wasted (weight for height) children under the age of 5 years (%)                                                               0
# Underweight children under the age of 5 years (%)                                                                                       0
# Severely underweight children under the age of 5 years (%)                                                                              0
# Children age group 6 to 59 months with mid-upper arm circumference ( muac ) less than 12.5 cm (%)                                       0
# Children age group 6 to 59 months with muac(mid-upper arm circumference) less than 11.5 cm (%)                                          0
# Children age group  6 to 59 months with mid-upper arm circumference ( muac ) for age less than -2 sd (%)                                0
# Children age group 6 to 59 months with mid-upper arm circumference ( muac ) for age less than -3 sd (%)                                 0
# Children under the age 5 years with triceps skinfold (thickness-for-age) less than -2 sd (%)                                            0
# Children under the age 5 years with triceps skinfold (thickness-for-age) less than -3 sd (%)                                            0
# Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +2 sd (%)                                         0
# Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +3 sd (%)                                         0
# Children age group 1 to 4 years with subscapular skinfold (thickness for age) less than -2 sd (%)                                       0
# Children age group of 1 to 4 years with subscapular skinfold (thickness for age) less than -3 sd (%)                                    0
# Children age group 1 to 4 years subscapular skinfold (thickness for age) greater than +2 sd (%)                                         0
# Children age group 1 to 4 years with subscapular skinfold (thickness for age) greater than +3 sd (%)                                    0
# Stunned children age group 5 to 9 years (%)                                                                                             0
# Severely stunted children age group of 5 to 9 years (%)                                                                                 0
# Moderate or severely thin children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)           0
# Severely thin children in the age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                0
# Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +1 sd (%)              0
# Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +2 sd (%)              0
# Moderate or severely thin adolescents age group 10 to14 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)       0
# Moderate or severely thin adolescents age group of 15 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)    0
# Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)       0
# Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                  0
# Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)                  0
# Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)                 0
# Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)        0
# Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)         0
# Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)        0
# Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      0
# Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      0
# Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      0
# dtype: int64
#
# Missing values in Malnutrition dataset:
# age_months          0
# weight_kg           0
# height_cm           0
# muac_cm             0
# bmi                 0
# nutrition_status    0
# dtype: int64
#
# Missing values in Malnutrition Month dataset:
# Sex,Weight,Height,Month,BMI,Result    0
# dtype: int64
#
# Verifying missing values after cleaning:
#
# CNNS dataset missing values:
# 0
#
# Malnutrition dataset missing values:
# 0
#
# Malnutrition Month dataset missing values:
# 0
#
# Verifying missing values after cleaning:
#
# CNNS dataset missing values:
# 0
#
# Malnutrition dataset missing values:
# 0
#
# Malnutrition Month dataset missing values:
# 0

# %% [markdown]
# ## 3. Remove Duplicates
#
# Now let's check for and remove any duplicate records in our datasets.

# %%
# Check for duplicates in each dataset
print("Duplicate rows in CNNS dataset:", cnns_data_clean.duplicated().sum())
print("Duplicate rows in Malnutrition dataset:", malnutrition_data_clean.duplicated().sum())
print("Duplicate rows in Malnutrition Month dataset:", malnutrition_month_clean.duplicated().sum())

# Remove duplicates
cnns_data_clean = cnns_data_clean.drop_duplicates()
malnutrition_data_clean = malnutrition_data_clean.drop_duplicates()
malnutrition_month_clean = malnutrition_month_clean.drop_duplicates()

# Verify duplicates have been removed
print("\nAfter removing duplicates:")
print("Duplicate rows in CNNS dataset:", cnns_data_clean.duplicated().sum())
print("Duplicate rows in Malnutrition dataset:", malnutrition_data_clean.duplicated().sum())
print("Duplicate rows in Malnutrition Month dataset:", malnutrition_month_clean.duplicated().sum())
# Out:
# Duplicate rows in CNNS dataset: 0
# Duplicate rows in Malnutrition dataset: 0
# Duplicate rows in Malnutrition Month dataset: 4
#
# After removing duplicates:
# Duplicate rows in CNNS dataset: 0
# Duplicate rows in Malnutrition dataset: 0
# Duplicate rows in Malnutrition Month dataset: 0
#
# After removing duplicates:
# Duplicate rows in CNNS dataset: 0
# Duplicate rows in Malnutrition dataset: 0
# Duplicate rows in Malnutrition Month dataset: 0

# %% [markdown]
# ## 4. Data Type Conversion
#
# Let's check and convert data types where necessary.

# %%
# Check current data types
print("CNNS dataset data types:")
print(cnns_data_clean.dtypes)
print("\nMalnutrition dataset data types:")
print(malnutrition_data_clean.dtypes)
print("\nMalnutrition Month dataset data types:")
print(malnutrition_month_clean.dtypes)

# Convert numeric columns to appropriate types
def convert_numeric_columns(df):
    for col in df.select_dtypes(include=['float64']).columns:
        # If all values in the column are integers, convert to int
        if df[col].dropna().apply(lambda x: x.is_integer()).all():
            df[col] = df[col].astype('int64')
    return df

# Apply conversions to each dataset
cnns_data_clean = convert_numeric_columns(cnns_data_clean)
malnutrition_data_clean = convert_numeric_columns(malnutrition_data_clean)
malnutrition_month_clean = convert_numeric_columns(malnutrition_month_clean)

# Verify new data types
print("\nAfter type conversion:")
print("CNNS dataset data types:")
print(cnns_data_clean.dtypes)
print("\nMalnutrition dataset data types:")
print(malnutrition_data_clean.dtypes)
print("\nMalnutrition Month dataset data types:")
print(malnutrition_month_clean.dtypes)
# Out:
# CNNS dataset data types:
# Rowid                                                                                                                                     int64
# Country                                                                                                                                  object
# State lgd code                                                                                                                            int64
# State                                                                                                                                    object
# Yearcode                                                                                                                                  int64
# Year                                                                                                                                     object
# From year                                                                                                                                 int64
# Gender                                                                                                                                   object
# Stunted (height for age) children under the age of 5 years (%)                                                                          float64
# Severely stunted (height for age) children under the age of 5 years (%)                                                                 float64
# Wasted (weight for height) children under the age of 5 years (%)                                                                        float64
# Severely wasted (weight for height) children under the age of 5 years (%)                                                               float64
# Underweight children under the age of 5 years (%)                                                                                       float64
# Severely underweight children under the age of 5 years (%)                                                                              float64
# Children age group 6 to 59 months with mid-upper arm circumference ( muac ) less than 12.5 cm (%)                                       float64
# Children age group 6 to 59 months with muac(mid-upper arm circumference) less than 11.5 cm (%)                                          float64
# Children age group  6 to 59 months with mid-upper arm circumference ( muac ) for age less than -2 sd (%)                                float64
# Children age group 6 to 59 months with mid-upper arm circumference ( muac ) for age less than -3 sd (%)                                 float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) less than -2 sd (%)                                            float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) less than -3 sd (%)                                            float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +2 sd (%)                                         float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +3 sd (%)                                         float64
# Children age group 1 to 4 years with subscapular skinfold (thickness for age) less than -2 sd (%)                                       float64
# Children age group of 1 to 4 years with subscapular skinfold (thickness for age) less than -3 sd (%)                                    float64
# Children age group 1 to 4 years subscapular skinfold (thickness for age) greater than +2 sd (%)                                         float64
# Children age group 1 to 4 years with subscapular skinfold (thickness for age) greater than +3 sd (%)                                    float64
# Stunned children age group 5 to 9 years (%)                                                                                             float64
# Severely stunted children age group of 5 to 9 years (%)                                                                                 float64
# Moderate or severely thin children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)           float64
# Severely thin children in the age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                float64
# Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +1 sd (%)              float64
# Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +2 sd (%)              float64
# Moderate or severely thin adolescents age group 10 to14 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)       float64
# Moderate or severely thin adolescents age group of 15 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)    float64
# Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)       float64
# Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                  float64
# Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)                  float64
# Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)                 float64
# Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)        float64
# Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)         float64
# Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)        float64
# Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      float64
# Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      float64
# Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      float64
# dtype: object
#
# Malnutrition dataset data types:
# age_months          float64
# weight_kg           float64
# height_cm           float64
# muac_cm             float64
# bmi                 float64
# nutrition_status     object
# dtype: object
#
# Malnutrition Month dataset data types:
# Sex,Weight,Height,Month,BMI,Result    object
# dtype: object
#
# After type conversion:
# CNNS dataset data types:
# Rowid                                                                                                                                     int64
# Country                                                                                                                                  object
# State lgd code                                                                                                                            int64
# State                                                                                                                                    object
# Yearcode                                                                                                                                  int64
# Year                                                                                                                                     object
# From year                                                                                                                                 int64
# Gender                                                                                                                                   object
# Stunted (height for age) children under the age of 5 years (%)                                                                          float64
# Severely stunted (height for age) children under the age of 5 years (%)                                                                 float64
# Wasted (weight for height) children under the age of 5 years (%)                                                                        float64
# Severely wasted (weight for height) children under the age of 5 years (%)                                                               float64
# Underweight children under the age of 5 years (%)                                                                                       float64
# Severely underweight children under the age of 5 years (%)                                                                              float64
# Children age group 6 to 59 months with mid-upper arm circumference ( muac ) less than 12.5 cm (%)                                       float64
# Children age group 6 to 59 months with muac(mid-upper arm circumference) less than 11.5 cm (%)                                          float64
# Children age group  6 to 59 months with mid-upper arm circumference ( muac ) for age less than -2 sd (%)                                float64
# Children age group 6 to 59 months with mid-upper arm circumference ( muac ) for age less than -3 sd (%)                                 float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) less than -2 sd (%)                                            float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) less than -3 sd (%)                                            float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +2 sd (%)                                         float64
# Children under the age 5 years with triceps skinfold (thickness-for-age) greater than +3 sd (%)                                         float64
# Children age group 1 to 4 years with subscapular skinfold (thickness for age) less than -2 sd (%)                                       float64
# Children age group of 1 to 4 years with subscapular skinfold (thickness for age) less than -3 sd (%)                                    float64
# Children age group 1 to 4 years subscapular skinfold (thickness for age) greater than +2 sd (%)                                         float64
# Children age group 1 to 4 years with subscapular skinfold (thickness for age) greater than +3 sd (%)                                    float64
# Stunned children age group 5 to 9 years (%)                                                                                             float64
# Severely stunted children age group of 5 to 9 years (%)                                                                                 float64
# Moderate or severely thin children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)           float64
# Severely thin children in the age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                float64
# Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +1 sd (%)              float64
# Overweight or obese children age group 5 to 9 years with ( body mass index ( bmi ) for age) z-score greater than +2 sd (%)              float64
# Moderate or severely thin adolescents age group 10 to14 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)       float64
# Moderate or severely thin adolescents age group of 15 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)    float64
# Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)       float64
# Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)                  float64
# Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)                  float64
# Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)                 float64
# Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)        float64
# Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)         float64
# Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)        float64
# Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      float64
# Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      float64
# Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)                      float64
# dtype: object
#
# Malnutrition dataset data types:
# age_months          float64
# weight_kg           float64
# height_cm           float64
# muac_cm             float64
# bmi                 float64
# nutrition_status     object
# dtype: object
#
# Malnutrition Month dataset data types:
# Sex,Weight,Height,Month,BMI,Result    object
# dtype: object

# %% [markdown]
# ## 5. Data Normalization
#
# Now we'll normalize the numerical columns in our datasets.

# %%
# Function to normalize numerical columns
def normalize_numerical_columns(df):
    scaler = StandardScaler()
    numeric_columns = df.select_dtypes(include=[np.number]).columns
    if len(numeric_columns) > 0:
        df_normalized = df.copy()
        df_normalized[numeric_columns] = scaler.fit_transform(df[numeric_columns])
        return df_normalized
    return df

# Normalize each dataset
cnns_data_normalized = normalize_numerical_columns(cnns_data_clean)
malnutrition_data_normalized = normalize_numerical_columns(malnutrition_data_clean)
malnutrition_month_normalized = normalize_numerical_columns(malnutrition_month_clean)

# Display summary statistics of normalized data
print("Summary statistics of normalized CNNS data:")
print(cnns_data_normalized.describe())
print("\nSummary statistics of normalized Malnutrition data:")
print(malnutrition_data_normalized.describe())
print("\nSummary statistics of normalized Malnutrition Month data:")
print(malnutrition_month_normalized.describe())
# Out:
# Summary statistics of normalized CNNS data:
#               Rowid  State lgd code  Yearcode  From year  \
# count  6.200000e+01    6.200000e+01      62.0       62.0
# mean  -3.581365e-18    1.862310e-16       0.0        0.0
# std    1.008163e+00    1.008163e+00       0.0        0.0
# min   -1.704336e+00   -1.634146e+00       0.0        0.0
# 25%   -8.521681e-01   -8.257653e-01       0.0        0.0
# 50%    0.000000e+00   -6.637730e-02       0.0        0.0
# 75%    8.521681e-01    8.399890e-01       0.0        0.0
# max    1.704336e+00    1.893334e+00       0.0        0.0
#
#        Stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        5.479488e-16
# std                                         1.008163e+00
# min                                        -2.177815e+00
# 25%                                        -5.784992e-01
# 50%                                         2.508040e-02
# 75%                                         7.309616e-01
# max                                         1.791488e+00
#
#        Severely stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -4.834842e-17
# std                                         1.008163e+00
# min                                        -1.600040e+00
# 25%                                        -8.939285e-01
# 50%                                        -8.871351e-02
# 75%                                         6.545619e-01
# max                                         2.339319e+00
#
#        Wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -5.336233e-16
# std                                         1.008163e+00
# min                                        -1.927613e+00
# 25%                                        -5.904801e-01
# 50%                                         4.581055e-02
# 75%                                         6.774904e-01
# max                                         2.683189e+00
#
#        Severely wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        2.506955e-17
# std                                         1.008163e+00
# min                                        -1.774398e+00
# 25%                                        -8.418819e-01
# 50%                                         1.797057e-02
# 75%                                         6.961641e-01
# max                                         2.004109e+00
#
#        Underweight children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        4.978097e-16
# std                                         1.008163e+00
# min                                        -1.701349e+00
# 25%                                        -9.702319e-01
# 50%                                         1.931512e-01
# 75%                                         7.241449e-01
# max                                         2.279770e+00
#
#        Severely underweight children under the age of 5 years (%)  ...  \
# count                                       6.200000e+01           ...
# mean                                       -2.083627e-16           ...
# std                                         1.008163e+00           ...
# min                                        -1.653140e+00           ...
# 25%                                        -7.175209e-01           ...
# 50%                                        -4.141662e-02           ...
# 75%                                         7.098104e-01           ...
# max                                         2.744953e+00           ...
#
#        Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -4.709494e-16
# std                                         1.008163e+00
# min                                        -1.762841e+00
# 25%                                        -5.839740e-01
# 50%                                        -1.170960e-01
# 75%                                         5.948929e-01
# max                                         2.217294e+00
#
#        Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.122254e-16
# std                                         1.008163e+00
# min                                        -1.564013e+00
# 25%                                        -8.012801e-01
# 50%                                        -1.275323e-01
# 75%                                         7.114744e-01
# max                                         2.478473e+00
#
#        Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)  \
# count                                       6.200000e+01
# mean                                        3.581365e-18
# std                                         1.008163e+00
# min                                        -1.192746e+00
# 25%                                        -7.987089e-01
# 50%                                        -3.242566e-01
# 75%                                         6.005233e-01
# max                                         2.892369e+00
#
#        Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                        7.610400e-18
# std                                         1.008163e+00
# min                                        -1.519056e+00
# 25%                                        -8.196886e-01
# 50%                                        -2.406425e-01
# 75%                                         7.595280e-01
# max                                         2.571867e+00
#
#        Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -2.865092e-17
# std                                         1.008163e+00
# min                                        -1.651283e+00
# 25%                                        -7.725122e-01
# 50%                                        -8.165487e-02
# 75%                                         5.815681e-01
# max                                         2.571237e+00
#
#        Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.163943e-17
# std                                         1.008163e+00
# min                                        -1.780854e+00
# 25%                                        -6.825391e-01
# 50%                                        -6.877493e-02
# 75%                                         8.034162e-01
# max                                         2.418585e+00
#
#        Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.083363e-16
# std                                         1.008163e+00
# min                                        -1.659443e+00
# 25%                                        -6.787811e-01
# 50%                                         1.617867e-01
# 75%                                         5.750658e-01
# max                                         2.375282e+00
#
#        Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.461644e-16
# std                                         1.008163e+00
# min                                        -1.462262e+00
# 25%                                        -6.410640e-01
# 50%                                        -1.118477e-01
# 75%                                         5.816081e-01
# max                                         3.720408e+00
#
#        Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.103508e-16
# std                                         1.008163e+00
# min                                        -1.041184e+00
# 25%                                        -7.867027e-01
# 50%                                        -3.625673e-01
# 75%                                         6.341508e-01
# max                                         3.200170e+00
#
#        Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)
# count                                       6.200000e+01
# mean                                        1.893647e-16
# std                                         1.008163e+00
# min                                        -1.495549e+00
# 25%                                        -7.711424e-01
# 50%                                        -4.673590e-02
# 75%                                         6.550329e-01
# max                                         3.575296e+00
#
# [8 rows x 40 columns]
#
# Summary statistics of normalized Malnutrition data:
#          age_months     weight_kg     height_cm       muac_cm           bmi
# count  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean   9.023893e-17 -1.982414e-16 -2.593481e-16 -8.860468e-16 -1.564331e-14
# std    1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min   -1.710066e+00 -9.763140e-01 -1.739688e+00 -3.590683e+00 -9.042748e-02
# 25%   -8.764995e-01 -9.763140e-01 -8.637512e-01 -6.685883e-01 -9.042748e-02
# 50%    1.623036e-02 -2.718243e-01 -8.096685e-03  2.192811e-01 -9.042748e-02
# 75%    8.637790e-01  7.511254e-01  8.202860e-01  7.240297e-01 -9.042748e-02
# max    1.729377e+00  2.324807e+00  1.722339e+00  2.567695e+00  2.710458e+01
#
# Summary statistics of normalized Malnutrition Month data:
#        Sex,Weight,Height,Month,BMI,Result
# count                                 996
# unique                                996
# top     Female,3,52.7,0,10.8,Malnutrition
# freq                                    1
#               Rowid  State lgd code  Yearcode  From year  \
# count  6.200000e+01    6.200000e+01      62.0       62.0
# mean  -3.581365e-18    1.862310e-16       0.0        0.0
# std    1.008163e+00    1.008163e+00       0.0        0.0
# min   -1.704336e+00   -1.634146e+00       0.0        0.0
# 25%   -8.521681e-01   -8.257653e-01       0.0        0.0
# 50%    0.000000e+00   -6.637730e-02       0.0        0.0
# 75%    8.521681e-01    8.399890e-01       0.0        0.0
# max    1.704336e+00    1.893334e+00       0.0        0.0
#
#        Stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        5.479488e-16
# std                                         1.008163e+00
# min                                        -2.177815e+00
# 25%                                        -5.784992e-01
# 50%                                         2.508040e-02
# 75%                                         7.309616e-01
# max                                         1.791488e+00
#
#        Severely stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -4.834842e-17
# std                                         1.008163e+00
# min                                        -1.600040e+00
# 25%                                        -8.939285e-01
# 50%                                        -8.871351e-02
# 75%                                         6.545619e-01
# max                                         2.339319e+00
#
#        Wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -5.336233e-16
# std                                         1.008163e+00
# min                                        -1.927613e+00
# 25%                                        -5.904801e-01
# 50%                                         4.581055e-02
# 75%                                         6.774904e-01
# max                                         2.683189e+00
#
#        Severely wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        2.506955e-17
# std                                         1.008163e+00
# min                                        -1.774398e+00
# 25%                                        -8.418819e-01
# 50%                                         1.797057e-02
# 75%                                         6.961641e-01
# max                                         2.004109e+00
#
#        Underweight children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        4.978097e-16
# std                                         1.008163e+00
# min                                        -1.701349e+00
# 25%                                        -9.702319e-01
# 50%                                         1.931512e-01
# 75%                                         7.241449e-01
# max                                         2.279770e+00
#
#        Severely underweight children under the age of 5 years (%)  ...  \
# count                                       6.200000e+01           ...
# mean                                       -2.083627e-16           ...
# std                                         1.008163e+00           ...
# min                                        -1.653140e+00           ...
# 25%                                        -7.175209e-01           ...
# 50%                                        -4.141662e-02           ...
# 75%                                         7.098104e-01           ...
# max                                         2.744953e+00           ...
#
#        Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -4.709494e-16
# std                                         1.008163e+00
# min                                        -1.762841e+00
# 25%                                        -5.839740e-01
# 50%                                        -1.170960e-01
# 75%                                         5.948929e-01
# max                                         2.217294e+00
#
#        Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.122254e-16
# std                                         1.008163e+00
# min                                        -1.564013e+00
# 25%                                        -8.012801e-01
# 50%                                        -1.275323e-01
# 75%                                         7.114744e-01
# max                                         2.478473e+00
#
#        Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)  \
# count                                       6.200000e+01
# mean                                        3.581365e-18
# std                                         1.008163e+00
# min                                        -1.192746e+00
# 25%                                        -7.987089e-01
# 50%                                        -3.242566e-01
# 75%                                         6.005233e-01
# max                                         2.892369e+00
#
#        Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                        7.610400e-18
# std                                         1.008163e+00
# min                                        -1.519056e+00
# 25%                                        -8.196886e-01
# 50%                                        -2.406425e-01
# 75%                                         7.595280e-01
# max                                         2.571867e+00
#
#        Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -2.865092e-17
# std                                         1.008163e+00
# min                                        -1.651283e+00
# 25%                                        -7.725122e-01
# 50%                                        -8.165487e-02
# 75%                                         5.815681e-01
# max                                         2.571237e+00
#
#        Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.163943e-17
# std                                         1.008163e+00
# min                                        -1.780854e+00
# 25%                                        -6.825391e-01
# 50%                                        -6.877493e-02
# 75%                                         8.034162e-01
# max                                         2.418585e+00
#
#        Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.083363e-16
# std                                         1.008163e+00
# min                                        -1.659443e+00
# 25%                                        -6.787811e-01
# 50%                                         1.617867e-01
# 75%                                         5.750658e-01
# max                                         2.375282e+00
#
#        Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.461644e-16
# std                                         1.008163e+00
# min                                        -1.462262e+00
# 25%                                        -6.410640e-01
# 50%                                        -1.118477e-01
# 75%                                         5.816081e-01
# max                                         3.720408e+00
#
#        Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.103508e-16
# std                                         1.008163e+00
# min                                        -1.041184e+00
# 25%                                        -7.867027e-01
# 50%                                        -3.625673e-01
# 75%                                         6.341508e-01
# max                                         3.200170e+00
#
#        Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)
# count                                       6.200000e+01
# mean                                        1.893647e-16
# std                                         1.008163e+00
# min                                        -1.495549e+00
# 25%                                        -7.711424e-01
# 50%                                        -4.673590e-02
# 75%                                         6.550329e-01
# max                                         3.575296e+00
#
# [8 rows x 40 columns]
#
# Summary statistics of normalized Malnutrition data:
#          age_months     weight_kg     height_cm       muac_cm           bmi
# count  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean   9.023893e-17 -1.982414e-16 -2.593481e-16 -8.860468e-16 -1.564331e-14
# std    1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min   -1.710066e+00 -9.763140e-01 -1.739688e+00 -3.590683e+00 -9.042748e-02
# 25%   -8.764995e-01 -9.763140e-01 -8.637512e-01 -6.685883e-01 -9.042748e-02
# 50%    1.623036e-02 -2.718243e-01 -8.096685e-03  2.192811e-01 -9.042748e-02
# 75%    8.637790e-01  7.511254e-01  8.202860e-01  7.240297e-01 -9.042748e-02
# max    1.729377e+00  2.324807e+00  1.722339e+00  2.567695e+00  2.710458e+01
#
# Summary statistics of normalized Malnutrition Month data:
#        Sex,Weight,Height,Month,BMI,Result
# count                                 996
# unique                                996
# top     Female,3,52.7,0,10.8,Malnutrition
# freq                                    1

# %% [markdown]
# ## 6. Data Validation
#
# Finally, let's perform some final checks on our preprocessed data.

# %%
# Final validation checks
def validate_dataset(df, name):
    print(f"\nValidation for {name}:")
    print(f"Number of rows: {len(df)}")
    print(f"Number of columns: {len(df.columns)}")
    print(f"Missing values: {df.isnull().sum().sum()}")
    print(f"Duplicate rows: {df.duplicated().sum()}")
    print("\nValue ranges for numerical columns:")
    print(df.describe())

# Perform validation for each dataset
validate_dataset(cnns_data_normalized, "CNNS Dataset")
validate_dataset(malnutrition_data_normalized, "Malnutrition Dataset")
validate_dataset(malnutrition_month_normalized, "Malnutrition Month Dataset")

# Save preprocessed datasets
cnns_data_normalized.to_csv('preprocessed_cnns_data.csv', index=False)
malnutrition_data_normalized.to_csv('preprocessed_malnutrition_data.csv', index=False)
malnutrition_month_normalized.to_csv('preprocessed_malnutrition_month.csv', index=False)

print("\nPreprocessed datasets have been saved to:")
print("- preprocessed_cnns_data.csv")
print("- preprocessed_malnutrition_data.csv")
print("- preprocessed_malnutrition_month.csv")
# Out:
# Validation for CNNS Dataset:
# Number of rows: 62
# Number of columns: 44
# Missing values: 0
# Duplicate rows: 0
#
# Value ranges for numerical columns:
#               Rowid  State lgd code  Yearcode  From year  \
# count  6.200000e+01    6.200000e+01      62.0       62.0
# mean  -3.581365e-18    1.862310e-16       0.0        0.0
# std    1.008163e+00    1.008163e+00       0.0        0.0
# min   -1.704336e+00   -1.634146e+00       0.0        0.0
# 25%   -8.521681e-01   -8.257653e-01       0.0        0.0
# 50%    0.000000e+00   -6.637730e-02       0.0        0.0
# 75%    8.521681e-01    8.399890e-01       0.0        0.0
# max    1.704336e+00    1.893334e+00       0.0        0.0
#
#        Stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        5.479488e-16
# std                                         1.008163e+00
# min                                        -2.177815e+00
# 25%                                        -5.784992e-01
# 50%                                         2.508040e-02
# 75%                                         7.309616e-01
# max                                         1.791488e+00
#
#        Severely stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -4.834842e-17
# std                                         1.008163e+00
# min                                        -1.600040e+00
# 25%                                        -8.939285e-01
# 50%                                        -8.871351e-02
# 75%                                         6.545619e-01
# max                                         2.339319e+00
#
#        Wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -5.336233e-16
# std                                         1.008163e+00
# min                                        -1.927613e+00
# 25%                                        -5.904801e-01
# 50%                                         4.581055e-02
# 75%                                         6.774904e-01
# max                                         2.683189e+00
#
#        Severely wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        2.506955e-17
# std                                         1.008163e+00
# min                                        -1.774398e+00
# 25%                                        -8.418819e-01
# 50%                                         1.797057e-02
# 75%                                         6.961641e-01
# max                                         2.004109e+00
#
#        Underweight children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        4.978097e-16
# std                                         1.008163e+00
# min                                        -1.701349e+00
# 25%                                        -9.702319e-01
# 50%                                         1.931512e-01
# 75%                                         7.241449e-01
# max                                         2.279770e+00
#
#        Severely underweight children under the age of 5 years (%)  ...  \
# count                                       6.200000e+01           ...
# mean                                       -2.083627e-16           ...
# std                                         1.008163e+00           ...
# min                                        -1.653140e+00           ...
# 25%                                        -7.175209e-01           ...
# 50%                                        -4.141662e-02           ...
# 75%                                         7.098104e-01           ...
# max                                         2.744953e+00           ...
#
#        Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -4.709494e-16
# std                                         1.008163e+00
# min                                        -1.762841e+00
# 25%                                        -5.839740e-01
# 50%                                        -1.170960e-01
# 75%                                         5.948929e-01
# max                                         2.217294e+00
#
#        Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.122254e-16
# std                                         1.008163e+00
# min                                        -1.564013e+00
# 25%                                        -8.012801e-01
# 50%                                        -1.275323e-01
# 75%                                         7.114744e-01
# max                                         2.478473e+00
#
#        Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)  \
# count                                       6.200000e+01
# mean                                        3.581365e-18
# std                                         1.008163e+00
# min                                        -1.192746e+00
# 25%                                        -7.987089e-01
# 50%                                        -3.242566e-01
# 75%                                         6.005233e-01
# max                                         2.892369e+00
#
#        Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                        7.610400e-18
# std                                         1.008163e+00
# min                                        -1.519056e+00
# 25%                                        -8.196886e-01
# 50%                                        -2.406425e-01
# 75%                                         7.595280e-01
# max                                         2.571867e+00
#
#        Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -2.865092e-17
# std                                         1.008163e+00
# min                                        -1.651283e+00
# 25%                                        -7.725122e-01
# 50%                                        -8.165487e-02
# 75%                                         5.815681e-01
# max                                         2.571237e+00
#
#        Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.163943e-17
# std                                         1.008163e+00
# min                                        -1.780854e+00
# 25%                                        -6.825391e-01
# 50%                                        -6.877493e-02
# 75%                                         8.034162e-01
# max                                         2.418585e+00
#
#        Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.083363e-16
# std                                         1.008163e+00
# min                                        -1.659443e+00
# 25%                                        -6.787811e-01
# 50%                                         1.617867e-01
# 75%                                         5.750658e-01
# max                                         2.375282e+00
#
#        Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.461644e-16
# std                                         1.008163e+00
# min                                        -1.462262e+00
# 25%                                        -6.410640e-01
# 50%                                        -1.118477e-01
# 75%                                         5.816081e-01
# max                                         3.720408e+00
#
#        Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.103508e-16
# std                                         1.008163e+00
# min                                        -1.041184e+00
# 25%                                        -7.867027e-01
# 50%                                        -3.625673e-01
# 75%                                         6.341508e-01
# max                                         3.200170e+00
#
#        Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)
# count                                       6.200000e+01
# mean                                        1.893647e-16
# std                                         1.008163e+00
# min                                        -1.495549e+00
# 25%                                        -7.711424e-01
# 50%                                        -4.673590e-02
# 75%                                         6.550329e-01
# max                                         3.575296e+00
#
# [8 rows x 40 columns]
#
# Validation for Malnutrition Dataset:
# Number of rows: 5000
# Number of columns: 6
# Missing values: 0
# Duplicate rows: 0
#
# Value ranges for numerical columns:
#          age_months     weight_kg     height_cm       muac_cm           bmi
# count  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean   9.023893e-17 -1.982414e-16 -2.593481e-16 -8.860468e-16 -1.564331e-14
# std    1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min   -1.710066e+00 -9.763140e-01 -1.739688e+00 -3.590683e+00 -9.042748e-02
# 25%   -8.764995e-01 -9.763140e-01 -8.637512e-01 -6.685883e-01 -9.042748e-02
# 50%    1.623036e-02 -2.718243e-01 -8.096685e-03  2.192811e-01 -9.042748e-02
# 75%    8.637790e-01  7.511254e-01  8.202860e-01  7.240297e-01 -9.042748e-02
# max    1.729377e+00  2.324807e+00  1.722339e+00  2.567695e+00  2.710458e+01
#
# Validation for Malnutrition Month Dataset:
# Number of rows: 996
# Number of columns: 1
# Missing values: 0
# Duplicate rows: 0
#
# Value ranges for numerical columns:
#        Sex,Weight,Height,Month,BMI,Result
# count                                 996
# unique                                996
# top     Female,3,52.7,0,10.8,Malnutrition
# freq                                    1
#               Rowid  State lgd code  Yearcode  From year  \
# count  6.200000e+01    6.200000e+01      62.0       62.0
# mean  -3.581365e-18    1.862310e-16       0.0        0.0
# std    1.008163e+00    1.008163e+00       0.0        0.0
# min   -1.704336e+00   -1.634146e+00       0.0        0.0
# 25%   -8.521681e-01   -8.257653e-01       0.0        0.0
# 50%    0.000000e+00   -6.637730e-02       0.0        0.0
# 75%    8.521681e-01    8.399890e-01       0.0        0.0
# max    1.704336e+00    1.893334e+00       0.0        0.0
#
#        Stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        5.479488e-16
# std                                         1.008163e+00
# min                                        -2.177815e+00
# 25%                                        -5.784992e-01
# 50%                                         2.508040e-02
# 75%                                         7.309616e-01
# max                                         1.791488e+00
#
#        Severely stunted (height for age) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -4.834842e-17
# std                                         1.008163e+00
# min                                        -1.600040e+00
# 25%                                        -8.939285e-01
# 50%                                        -8.871351e-02
# 75%                                         6.545619e-01
# max                                         2.339319e+00
#
#        Wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                       -5.336233e-16
# std                                         1.008163e+00
# min                                        -1.927613e+00
# 25%                                        -5.904801e-01
# 50%                                         4.581055e-02
# 75%                                         6.774904e-01
# max                                         2.683189e+00
#
#        Severely wasted (weight for height) children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        2.506955e-17
# std                                         1.008163e+00
# min                                        -1.774398e+00
# 25%                                        -8.418819e-01
# 50%                                         1.797057e-02
# 75%                                         6.961641e-01
# max                                         2.004109e+00
#
#        Underweight children under the age of 5 years (%)  \
# count                                       6.200000e+01
# mean                                        4.978097e-16
# std                                         1.008163e+00
# min                                        -1.701349e+00
# 25%                                        -9.702319e-01
# 50%                                         1.931512e-01
# 75%                                         7.241449e-01
# max                                         2.279770e+00
#
#        Severely underweight children under the age of 5 years (%)  ...  \
# count                                       6.200000e+01           ...
# mean                                       -2.083627e-16           ...
# std                                         1.008163e+00           ...
# min                                        -1.653140e+00           ...
# 25%                                        -7.175209e-01           ...
# 50%                                        -4.141662e-02           ...
# 75%                                         7.098104e-01           ...
# max                                         2.744953e+00           ...
#
#        Moderate or severely thin adolescents age group 10 to19 years with ( body mass index ( bmi ) for age) z-score less than -2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -4.709494e-16
# std                                         1.008163e+00
# min                                        -1.762841e+00
# 25%                                        -5.839740e-01
# 50%                                        -1.170960e-01
# 75%                                         5.948929e-01
# max                                         2.217294e+00
#
#        Severely thin adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.122254e-16
# std                                         1.008163e+00
# min                                        -1.564013e+00
# 25%                                        -8.012801e-01
# 50%                                        -1.275323e-01
# 75%                                         7.114744e-01
# max                                         2.478473e+00
#
#        Severely thin adolescents age group 15 to 19 years with  ( body mass index ( bmi ) for age) z-score less than-3 sd (%)  \
# count                                       6.200000e+01
# mean                                        3.581365e-18
# std                                         1.008163e+00
# min                                        -1.192746e+00
# 25%                                        -7.987089e-01
# 50%                                        -3.242566e-01
# 75%                                         6.005233e-01
# max                                         2.892369e+00
#
#        Severely thin adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score less than -3 sd (%)  \
# count                                       6.200000e+01
# mean                                        7.610400e-18
# std                                         1.008163e+00
# min                                        -1.519056e+00
# 25%                                        -8.196886e-01
# 50%                                        -2.406425e-01
# 75%                                         7.595280e-01
# max                                         2.571867e+00
#
#        Overweight or obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -2.865092e-17
# std                                         1.008163e+00
# min                                        -1.651283e+00
# 25%                                        -7.725122e-01
# 50%                                        -8.165487e-02
# 75%                                         5.815681e-01
# max                                         2.571237e+00
#
#        Overweight or obese adolescents age group 15 to 19 years with (body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.163943e-17
# std                                         1.008163e+00
# min                                        -1.780854e+00
# 25%                                        -6.825391e-01
# 50%                                        -6.877493e-02
# 75%                                         8.034162e-01
# max                                         2.418585e+00
#
#        Overweight or obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +1 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.083363e-16
# std                                         1.008163e+00
# min                                        -1.659443e+00
# 25%                                        -6.787811e-01
# 50%                                         1.617867e-01
# 75%                                         5.750658e-01
# max                                         2.375282e+00
#
#        Obese adolescents age group 10 to 14 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                       -1.461644e-16
# std                                         1.008163e+00
# min                                        -1.462262e+00
# 25%                                        -6.410640e-01
# 50%                                        -1.118477e-01
# 75%                                         5.816081e-01
# max                                         3.720408e+00
#
#        Obese adolescents age group 15 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)  \
# count                                       6.200000e+01
# mean                                        1.103508e-16
# std                                         1.008163e+00
# min                                        -1.041184e+00
# 25%                                        -7.867027e-01
# 50%                                        -3.625673e-01
# 75%                                         6.341508e-01
# max                                         3.200170e+00
#
#        Obese adolescents age group 10 to 19 years with ( body mass index ( bmi ) for age ) z-score greater than +2 sd (%)
# count                                       6.200000e+01
# mean                                        1.893647e-16
# std                                         1.008163e+00
# min                                        -1.495549e+00
# 25%                                        -7.711424e-01
# 50%                                        -4.673590e-02
# 75%                                         6.550329e-01
# max                                         3.575296e+00
#
# [8 rows x 40 columns]
#
# Validation for Malnutrition Dataset:
# Number of rows: 5000
# Number of columns: 6
# Missing values: 0
# Duplicate rows: 0
#
# Value ranges for numerical columns:
#          age_months     weight_kg     height_cm       muac_cm           bmi
# count  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean   9.023893e-17 -1.982414e-16 -2.593481e-16 -8.860468e-16 -1.564331e-14
# std    1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min   -1.710066e+00 -9.763140e-01 -1.739688e+00 -3.590683e+00 -9.042748e-02
# 25%   -8.764995e-01 -9.763140e-01 -8.637512e-01 -6.685883e-01 -9.042748e-02
# 50%    1.623036e-02 -2.718243e-01 -8.096685e-03  2.192811e-01 -9.042748e-02
# 75%    8.637790e-01  7.511254e-01  8.202860e-01  7.240297e-01 -9.042748e-02
# max    1.729377e+00  2.324807e+00  1.722339e+00  2.567695e+00  2.710458e+01
#
# Validation for Malnutrition Month Dataset:
# Number of rows: 996
# Number of columns: 1
# Missing values: 0
# Duplicate rows: 0
#
# Value ranges for numerical columns:
#        Sex,Weight,Height,Month,BMI,Result
# count                                 996
# unique                                996
# top     Female,3,52.7,0,10.8,Malnutrition
# freq                                    1
#
# Preprocessed datasets have been saved to:
# - preprocessed_cnns_data.csv
# - preprocessed_malnutrition_data.csv
# - preprocessed_malnutrition_month.csv
#
# Preprocessed datasets have been saved to:
# - preprocessed_cnns_data.csv
# - preprocessed_malnutrition_data.csv
# - preprocessed_malnutrition_month.csv
